# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False

# %%
paragraph =  """I have three visions for India. In 3000 years of our history, people from all over
               the world have come and invaded us, captured our lands, conquered our minds.
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours.
               Yet we have not done this to any other nation. We have not conquered anyone.
               We have not grabbed their land, their culture,
               their history and tried to enforce our way of life on them.
               Why? Because we respect the freedom of others.That is why my
               first vision is that of freedom. I believe that India got its first vision of
               this in 1857, when we started the War of Independence. It is this freedom that
               we must protect and nurture and build on. If we are not free, no one will respect us.
               My second vision for India’s development. For fifty years we have been a developing nation.
               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world
               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.
               Our achievements are being globally recognised today. Yet we lack the self-confidence to
               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?
               I have a third vision. India must stand up to the world. Because I believe that unless India
               stands up to the world, no one will respect us. Only strength respects strength. We must be
               strong not only as a military power but also as an economic power. Both must go hand-in-hand.
               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of
               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.
               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.
               I see four milestones in my career"""

# %%
# Cleaning the texts
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()
wordnet=WordNetLemmatizer()
sentences = nltk.sent_tokenize(paragraph)

# %%
#sentences = ['he is a good boy','she is a good girl','boy & girl are good']
corpus = []

# %%
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = [wordnet.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
#cv = CountVectorizer(max_features=100)
cv = CountVectorizer(max_features=500,ngram_range=(1,3))
X = cv.fit_transform(corpus).toarray()
cv.vocabulary_
# Out:
# {'three': np.int64(289),
#  'vision': np.int64(320),
#  'india': np.int64(141),
#  'three vision': np.int64(294),
#  'vision india': np.int64(322),
#  'three vision india': np.int64(295),
#  'year': np.int64(341),
#  'histori': np.int64(134),
#  'peopl': np.int64(211),
#  'world': np.int64(334),
#  'come': np.int64(38),
#  'invad': np.int64(149),
#  'us': np.int64(313),
#  'captur': np.int64(31),
#  'land': np.int64(157),
#  'conquer': np.int64(45),
#  'mind': np.int64(178),
#  'year histori': np.int64(344),
#  'histori peopl': np.int64(135),
#  'peopl world': np.int64(212),
#  'world come': np.int64(335),
#  'come invad': np.int64(39),
#  'invad us': np.int64(152),
#  'us captur': np.int64(314),
#  'captur land': np.int64(32),
#  'land conquer': np.int64(158),
#  'conquer mind': np.int64(47),
#  'year histori peopl': np.int64(345),
#  'histori peopl world': np.int64(136),
#  'peopl world come': np.int64(213),
#  'world come invad': np.int64(336),
#  'come invad us': np.int64(41),
#  'invad us captur': np.int64(153),
#  'us captur land': np.int64(315),
#  'captur land conquer': np.int64(33),
#  'land conquer mind': np.int64(159),
#  'alexand': np.int64(3),
#  'onward': np.int64(203),
#  'greek': np.int64(126),
#  'turk': np.int64(307),
#  'mogul': np.int64(179),
#  'portugues': np.int64(217),
#  'british': np.int64(23),
#  'french': np.int64(103),
#  'dutch': np.int64(68),
#  'came': np.int64(27),
#  'loot': np.int64(165),
#  'took': np.int64(300),
#  'alexand onward': np.int64(4),
#  'onward greek': np.int64(204),
#  'greek turk': np.int64(127),
#  'turk mogul': np.int64(308),
#  'mogul portugues': np.int64(180),
#  'portugues british': np.int64(218),
#  'british french': np.int64(24),
#  'french dutch': np.int64(104),
#  'dutch came': np.int64(69),
#  'came loot': np.int64(28),
#  'loot us': np.int64(167),
#  'us took': np.int64(316),
#  'alexand onward greek': np.int64(5),
#  'onward greek turk': np.int64(205),
#  'greek turk mogul': np.int64(128),
#  'turk mogul portugues': np.int64(309),
#  'mogul portugues british': np.int64(181),
#  'portugues british french': np.int64(219),
#  'british french dutch': np.int64(25),
#  'french dutch came': np.int64(105),
#  'dutch came loot': np.int64(70),
#  'came loot us': np.int64(30),
#  'loot us took': np.int64(168),
#  'yet': np.int64(346),
#  'done': np.int64(61),
#  'nation': np.int64(191),
#  'yet done': np.int64(347),
#  'done nation': np.int64(62),
#  'yet done nation': np.int64(348),
#  'anyon': np.int64(12),
#  'conquer anyon': np.int64(46),
#  'grab': np.int64(119),
#  'cultur': np.int64(51),
#  'tri': np.int64(304),
#  'enforc': np.int64(73),
#  'way': np.int64(328),
#  'life': np.int64(164),
#  'grab land': np.int64(120),
#  'land cultur': np.int64(160),
#  'cultur histori': np.int64(52),
#  'histori tri': np.int64(137),
#  'tri enforc': np.int64(305),
#  'enforc way': np.int64(74),
#  'way life': np.int64(329),
#  'grab land cultur': np.int64(121),
#  'land cultur histori': np.int64(161),
#  'cultur histori tri': np.int64(53),
#  'histori tri enforc': np.int64(138),
#  'tri enforc way': np.int64(306),
#  'enforc way life': np.int64(75),
#  'respect': np.int64(242),
#  'freedom': np.int64(96),
#  'other': np.int64(208),
#  'first': np.int64(83),
#  'respect freedom': np.int64(243),
#  'freedom other': np.int64(101),
#  'other first': np.int64(209),
#  'first vision': np.int64(84),
#  'vision freedom': np.int64(321),
#  'respect freedom other': np.int64(245),
#  'freedom other first': np.int64(102),
#  'other first vision': np.int64(210),
#  'first vision freedom': np.int64(85),
#  'believ': np.int64(15),
#  'got': np.int64(116),
#  'start': np.int64(273),
#  'war': np.int64(326),
#  'independ': np.int64(140),
#  'believ india': np.int64(16),
#  'india got': np.int64(143),
#  'got first': np.int64(117),
#  'vision start': np.int64(324),
#  'start war': np.int64(274),
#  'war independ': np.int64(327),
#  'believ india got': np.int64(17),
#  'india got first': np.int64(144),
#  'got first vision': np.int64(118),
#  'first vision start': np.int64(86),
#  'vision start war': np.int64(325),
#  'start war independ': np.int64(275),
#  'must': np.int64(182),
#  'protect': np.int64(232),
#  'nurtur': np.int64(198),
#  'build': np.int64(26),
#  'freedom must': np.int64(99),
#  'must protect': np.int64(185),
#  'protect nurtur': np.int64(233),
#  'nurtur build': np.int64(199),
#  'freedom must protect': np.int64(100),
#  'must protect nurtur': np.int64(186),
#  'protect nurtur build': np.int64(234),
#  'free': np.int64(93),
#  'one': np.int64(200),
#  'free one': np.int64(94),
#  'one respect': np.int64(201),
#  'respect us': np.int64(247),
#  'free one respect': np.int64(95),
#  'one respect us': np.int64(202),
#  'second': np.int64(253),
#  'develop': np.int64(55),
#  'second vision': np.int64(254),
#  'india develop': np.int64(142),
#  'second vision india': np.int64(255),
#  'vision india develop': np.int64(323),
#  'fifti': np.int64(80),
#  'fifti year': np.int64(81),
#  'year develop': np.int64(342),
#  'develop nation': np.int64(56),
#  'fifti year develop': np.int64(82),
#  'year develop nation': np.int64(343),
#  'time': np.int64(296),
#  'see': np.int64(256),
#  'time see': np.int64(297),
#  'see develop': np.int64(257),
#  'time see develop': np.int64(298),
#  'see develop nation': np.int64(258),
#  'among': np.int64(9),
#  'top': np.int64(301),
#  'term': np.int64(285),
#  'gdp': np.int64(106),
#  'among top': np.int64(10),
#  'top nation': np.int64(302),
#  'nation world': np.int64(194),
#  'world term': np.int64(339),
#  'term gdp': np.int64(286),
#  'among top nation': np.int64(11),
#  'top nation world': np.int64(303),
#  'nation world term': np.int64(195),
#  'world term gdp': np.int64(340),
#  'percent': np.int64(214),
#  'growth': np.int64(129),
#  'rate': np.int64(235),
#  'area': np.int64(13),
#  'percent growth': np.int64(215),
#  'growth rate': np.int64(130),
#  'rate area': np.int64(236),
#  'percent growth rate': np.int64(216),
#  'growth rate area': np.int64(131),
#  'poverti': np.int64(220),
#  'level': np.int64(162),
#  'fall': np.int64(76),
#  'poverti level': np.int64(221),
#  'level fall': np.int64(163),
#  'poverti level fall': np.int64(222),
#  'achiev': np.int64(0),
#  'global': np.int64(107),
#  'recognis': np.int64(237),
#  'today': np.int64(299),
#  'achiev global': np.int64(1),
#  'global recognis': np.int64(108),
#  'recognis today': np.int64(238),
#  'achiev global recognis': np.int64(2),
#  'global recognis today': np.int64(109),
#  'lack': np.int64(154),
#  'self': np.int64(261),
#  'confid': np.int64(42),
#  'reliant': np.int64(239),
#  'assur': np.int64(14),
#  'yet lack': np.int64(349),
#  'lack self': np.int64(155),
#  'self confid': np.int64(263),
#  'confid see': np.int64(43),
#  'nation self': np.int64(192),
#  'self reliant': np.int64(265),
#  'reliant self': np.int64(240),
#  'self assur': np.int64(262),
#  'yet lack self': np.int64(350),
#  'lack self confid': np.int64(156),
#  'self confid see': np.int64(264),
#  'confid see develop': np.int64(44),
#  'develop nation self': np.int64(57),
#  'nation self reliant': np.int64(193),
#  'self reliant self': np.int64(266),
#  'reliant self assur': np.int64(241),
#  'incorrect': np.int64(139),
#  'third': np.int64(287),
#  'third vision': np.int64(288),
#  'stand': np.int64(270),
#  'india must': np.int64(145),
#  'must stand': np.int64(187),
#  'stand world': np.int64(271),
#  'india must stand': np.int64(146),
#  'must stand world': np.int64(188),
#  'unless': np.int64(310),
#  'believ unless': np.int64(18),
#  'unless india': np.int64(311),
#  'india stand': np.int64(147),
#  'world one': np.int64(337),
#  'believ unless india': np.int64(19),
#  'unless india stand': np.int64(312),
#  'india stand world': np.int64(148),
#  'stand world one': np.int64(272),
#  'world one respect': np.int64(338),
#  'strength': np.int64(276),
#  'strength respect': np.int64(277),
#  'respect strength': np.int64(246),
#  'strength respect strength': np.int64(278),
#  'strong': np.int64(279),
#  'militari': np.int64(175),
#  'power': np.int64(223),
#  'also': np.int64(6),
#  'econom': np.int64(71),
#  'must strong': np.int64(189),
#  'strong militari': np.int64(280),
#  'militari power': np.int64(176),
#  'power also': np.int64(224),
#  'also econom': np.int64(7),
#  'econom power': np.int64(72),
#  'must strong militari': np.int64(190),
#  'strong militari power': np.int64(281),
#  'militari power also': np.int64(177),
#  'power also econom': np.int64(225),
#  'also econom power': np.int64(8),
#  'go': np.int64(110),
#  'hand': np.int64(132),
#  'must go': np.int64(183),
#  'go hand': np.int64(111),
#  'hand hand': np.int64(133),
#  'must go hand': np.int64(184),
#  'go hand hand': np.int64(112),
#  'good': np.int64(113),
#  'fortun': np.int64(87),
#  'work': np.int64(330),
#  'great': np.int64(122),
#  'good fortun': np.int64(114),
#  'fortun work': np.int64(88),
#  'work three': np.int64(331),
#  'three great': np.int64(292),
#  'great mind': np.int64(123),
#  'good fortun work': np.int64(115),
#  'fortun work three': np.int64(89),
#  'work three great': np.int64(333),
#  'three great mind': np.int64(293),
#  'dr': np.int64(63),
#  'vikram': np.int64(317),
#  'sarabhai': np.int64(248),
#  'dept': np.int64(54),
#  'dr vikram': np.int64(66),
#  'vikram sarabhai': np.int64(318),
#  'sarabhai dept': np.int64(249),
#  'dr vikram sarabhai': np.int64(67),
#  'vikram sarabhai dept': np.int64(319),
#  'space': np.int64(267),
#  'professor': np.int64(229),
#  'satish': np.int64(250),
#  'dhawan': np.int64(58),
#  'succeed': np.int64(282),
#  'brahm': np.int64(20),
#  'prakash': np.int64(226),
#  'father': np.int64(77),
#  'nuclear': np.int64(196),
#  'materi': np.int64(172),
#  'space professor': np.int64(268),
#  'professor satish': np.int64(230),
#  'satish dhawan': np.int64(251),
#  'dhawan succeed': np.int64(59),
#  'succeed dr': np.int64(283),
#  'dr brahm': np.int64(64),
#  'brahm prakash': np.int64(21),
#  'prakash father': np.int64(227),
#  'father nuclear': np.int64(78),
#  'nuclear materi': np.int64(197),
#  'space professor satish': np.int64(269),
#  'professor satish dhawan': np.int64(231),
#  'satish dhawan succeed': np.int64(252),
#  'dhawan succeed dr': np.int64(60),
#  'succeed dr brahm': np.int64(284),
#  'dr brahm prakash': np.int64(65),
#  'brahm prakash father': np.int64(22),
#  'prakash father nuclear': np.int64(228),
#  'father nuclear materi': np.int64(79),
#  'lucki': np.int64(169),
#  'close': np.int64(35),
#  'consid': np.int64(48),
#  'opportun': np.int64(206),
#  'lucki work': np.int64(170),
#  'three close': np.int64(290),
#  'close consid': np.int64(36),
#  'consid great': np.int64(49),
#  'great opportun': np.int64(124),
#  'opportun life': np.int64(207),
#  'lucki work three': np.int64(171),
#  'work three close': np.int64(332),
#  'three close consid': np.int64(291),
#  'close consid great': np.int64(37),
#  'consid great opportun': np.int64(50),
#  'great opportun life': np.int64(125),
#  'four': np.int64(90),
#  'mileston': np.int64(173),
#  'career': np.int64(34),
#  'see four': np.int64(259),
#  'four mileston': np.int64(91),
#  'mileston career': np.int64(174),
#  'see four mileston': np.int64(260),
#  'four mileston career': np.int64(92),
#  'invad captur': np.int64(150),
#  'come invad captur': np.int64(40),
#  'invad captur land': np.int64(151),
#  'loot took': np.int64(166),
#  'came loot took': np.int64(29),
#  'freedom first': np.int64(97),
#  'respect freedom first': np.int64(244),
#  'freedom first vision': np.int64(98)}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()  
X = cv.fit_transform(corpus).toarray()  
cv.vocabulary_
# Out:
# {'three': 96,
#  'vision': 106,
#  'india': 50,
#  'year': 111,
#  'histori': 47,
#  'peopl': 71,
#  'world': 110,
#  'come': 15,
#  'invad': 51,
#  'us': 104,
#  'captur': 12,
#  'land': 53,
#  'conquer': 17,
#  'mind': 61,
#  'alexand': 1,
#  'onward': 68,
#  'greek': 44,
#  'turk': 102,
#  'mogul': 62,
#  'portugues': 73,
#  'british': 9,
#  'french': 36,
#  'dutch': 25,
#  'came': 11,
#  'loot': 56,
#  'took': 99,
#  'yet': 112,
#  'done': 23,
#  'nation': 64,
#  'anyon': 4,
#  'grab': 42,
#  'cultur': 19,
#  'tri': 101,
#  'enforc': 27,
#  'way': 108,
#  'life': 55,
#  'respect': 82,
#  'freedom': 35,
#  'other': 70,
#  'first': 31,
#  'believ': 7,
#  'got': 41,
#  'start': 90,
#  'war': 107,
#  'independ': 49,
#  'must': 63,
#  'protect': 78,
#  'nurtur': 66,
#  'build': 10,
#  'free': 34,
#  'one': 67,
#  'second': 85,
#  'develop': 21,
#  'fifti': 30,
#  'time': 97,
#  'see': 86,
#  'among': 3,
#  'top': 100,
#  'term': 94,
#  'gdp': 37,
#  'percent': 72,
#  'growth': 45,
#  'rate': 79,
#  'area': 5,
#  'poverti': 74,
#  'level': 54,
#  'fall': 28,
#  'achiev': 0,
#  'global': 38,
#  'recognis': 80,
#  'today': 98,
#  'lack': 52,
#  'self': 87,
#  'confid': 16,
#  'reliant': 81,
#  'assur': 6,
#  'incorrect': 48,
#  'third': 95,
#  'stand': 89,
#  'unless': 103,
#  'strength': 91,
#  'strong': 92,
#  'militari': 60,
#  'power': 75,
#  'also': 2,
#  'econom': 26,
#  'go': 39,
#  'hand': 46,
#  'good': 40,
#  'fortun': 32,
#  'work': 109,
#  'great': 43,
#  'dr': 24,
#  'vikram': 105,
#  'sarabhai': 83,
#  'dept': 20,
#  'space': 88,
#  'professor': 77,
#  'satish': 84,
#  'dhawan': 22,
#  'succeed': 93,
#  'brahm': 8,
#  'prakash': 76,
#  'father': 29,
#  'nuclear': 65,
#  'materi': 58,
#  'lucki': 57,
#  'close': 14,
#  'consid': 18,
#  'opportun': 69,
#  'four': 33,
#  'mileston': 59,
#  'career': 13}
